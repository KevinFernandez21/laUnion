# %%
import pandas as pd
# Lee solo hasta la fila 645
ds = pd.read_csv('./data/Censo_ESPOL_La Unión_2022 - ACTUALIZADO AL 18 JULIO 22(1)(COPIA TABLA LU).csv', encoding='latin1', nrows=645,delimiter=';')
ds.head()
# Out:
#      Practicante  Cï¿½digo de la casa           Apellidos             Nombres  \
# 0  AGUIRRE MARCO                 100.0  Achiote Dominguez  Andreina Katherine
# 1  AGUIRRE MARCO                 100.0        Cruz Torres     Arelis Angelina
# 2  AGUIRRE MARCO                 100.0        Cruz Torres  Kimberly Kathiuska
# 3  AGUIRRE MARCO                 100.0       Cruz Achiote    Yarezi Francesca
# 4  AGUIRRE MARCO                 100.0        Cruz Torres       Mayerly Maite
#
#       Cï¿½dula ï¿½Es jefe de hogar?  \
# 0  928818327.0                    1
# 1  958390536.0                    2
# 2  960691251.0                    2
# 3  964403760.0                    2
# 4  954451811.0                    2
#
#   Parentesco (con respecto al jefe de hogar) Sexo Edad 2022 Edad 03/2017  ...  \
# 0                                          1    2        25           20  ...
# 1                                          2    2         8            3  ...
# ...
